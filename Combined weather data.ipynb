# %%
import pandas as pd

# %%
df1=pd.read_csv('data_january.csv')
df1
# Out:
#          Date  Average temperature  Average humidity  Average dewpoint  \
# 0    1/1/2023                 28.5                83              23.9
# 1    1/2/2023                 20.4                92              18.5
# 2    1/3/2023                 21.8                68              12.1
# 3    1/4/2023                 23.1                46               5.4
# 4    1/5/2023                 33.3                39              10.7
# 5    1/6/2023                 34.2                50              17.4
# 6    1/7/2023                 32.3                46              13.9
# 7    1/8/2023                 35.4                31               7.3
# 8    1/9/2023                 36.0                47              17.8
# 9   1/10/2023                 38.1                60              25.3
# 10  1/11/2023                 30.3                65              19.3
# 11  1/12/2023                 32.5                42              11.3
# ...

# %%
df2=pd.read_csv('data_feb.csv')
df2
# Out:
#          Date  Average temperature  Average humidity  Average dewpoint  \
# 0    2/1/2023                 25.7                48               8.8
# 1    2/2/2023                 31.6                39               8.5
# 2    2/3/2023                 37.2                22               1.8
# 3    2/4/2023                 36.1                30               7.3
# 4    2/5/2023                 40.1                30               9.8
# 5    2/6/2023                 26.8                49               9.7
# 6    2/7/2023                 24.1                50               6.6
# 7    2/8/2023                 25.1                54              10.2
# 8    2/9/2023                 18.5                46               0.3
# 9   2/10/2023                 24.7                48               3.9
# 10  2/11/2023                 37.0                33               6.8
# 11  2/12/2023                 37.6                33              10.3
# ...

# %%
df3=pd.read_csv('data_march.csv')
df3
# Out:
#          Date  Average temperature  Average humidity  Average dewpoint  \
# 0    3/1/2023                 20.4                59               6.4
# 1    3/2/2023                 25.6                57              10.9
# 2    3/3/2023                 27.6                50              11.3
# 3    3/4/2023                 26.5                50               8.6
# 4    3/5/2023                 27.2                62              15.2
# 5    3/6/2023                 24.7                68              14.4
# 6    3/7/2023                 21.6                85              17.6
# 7    3/8/2023                 23.5                78              17.6
# 8    3/9/2023                 27.8                55              12.0
# 9   3/10/2023                 36.3                58              22.4
# 10  3/11/2023                 34.6                52              17.4
# 11  3/12/2023                 24.7                73              16.9
# ...

# %%
df4=pd.read_csv('data_april.csv')
df4
# Out:
#          Date  Average temperature  Average humidity  Average dewpoint  \
# 0    4/1/2023                 38.1                36              13.0
# 1    4/2/2023                 42.8                33              14.6
# 2    4/3/2023                 34.4                70              25.4
# 3    4/4/2023                 16.9                87              13.8
# 4    4/5/2023                 18.1                61               5.9
# 5    4/6/2023                 24.2                46               4.4
# 6    4/7/2023                 32.2                50              12.4
# 7    4/8/2023                 37.0                57              21.4
# 8    4/9/2023                 44.5                43              22.4
# 9   4/10/2023                 52.9                30              20.8
# 10  4/11/2023                 52.2                34              18.3
# 11  4/12/2023                 56.8                28              22.9
# ...

# %%
data= pd.concat([df1, df2,df3,df4])

# %%
data
# Out:
#          Date  Average temperature  Average humidity  Average dewpoint  \
# 0    1/1/2023                 28.5                83              23.9
# 1    1/2/2023                 20.4                92              18.5
# 2    1/3/2023                 21.8                68              12.1
# 3    1/4/2023                 23.1                46               5.4
# 4    1/5/2023                 33.3                39              10.7
# ..        ...                  ...               ...               ...
# 25  4/26/2023                 38.9                82              33.4
# 26  4/27/2023                 43.1                55              25.9
# 27  4/28/2023                 38.7                55              21.3
# 28  4/29/2023                 50.2                35              23.0
# 29  4/30/2023                 44.8                60              30.5
#
#     Average barometer  Average windspeed  Average gustspeed  \
# ...

# %%
data.shape
# Out:
# (120, 20)

# %%
data.tail()
# Out:
#          Date  Average temperature  Average humidity  Average dewpoint  \
# 25  4/26/2023                 38.9                82              33.4
# 26  4/27/2023                 43.1                55              25.9
# 27  4/28/2023                 38.7                55              21.3
# 28  4/29/2023                 50.2                35              23.0
# 29  4/30/2023                 44.8                60              30.5
#
#     Average barometer  Average windspeed  Average gustspeed  \
# 25               29.9                1.5                3.1
# 26               29.7                8.5               13.5
# 27               30.0                4.2                6.8
# 28               29.9                5.9                9.0
# 29               29.8                2.4                4.2
#
#     Average direction  Rainfall for month  Rainfall for year  \
# 25                 91                0.76               2.56
# ...

# %%
data.to_csv("weather_data.csv", index=False)
